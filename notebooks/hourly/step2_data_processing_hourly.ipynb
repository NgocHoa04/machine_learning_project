# %% [markdown]
# ## DATA UNDERSTANDING - DATA HOURLY

# %%
import pandas as pd
import numpy as np
hn_hourly = pd.read_csv('../dataset/raw/Hanoi Hourly.csv')
hn_hourly.head()
# Out:
#     name             datetime  temp  feelslike   dew  humidity  precip  \
# 0  Hanoi  2015-01-01T00:00:00  15.0       15.0  13.0     87.84     0.0
# 1  Hanoi  2015-01-01T01:00:00  15.8       15.8  13.0     83.33     0.0
# 2  Hanoi  2015-01-01T02:00:00  13.5       13.5  12.0     90.65     0.0
# 3  Hanoi  2015-01-01T03:00:00  13.0       13.0  12.0     93.65     0.0
# 4  Hanoi  2015-01-01T04:00:00  14.7       14.7  12.5     86.57     0.0
#
#    precipprob preciptype  snow  ...  sealevelpressure  cloudcover  visibility  \
# 0           0        NaN   0.0  ...            1023.0         0.0         3.5
# 1           0        NaN   0.0  ...            1022.6         0.0         8.5
# 2           0        NaN   0.0  ...            1022.0         0.0         3.0
# 3           0        NaN   0.0  ...            1022.0         0.0         2.0
# 4           0        NaN   0.0  ...            1022.4         0.0         8.2
#
#    solarradiation  solarenergy  uvindex  severerisk  conditions         icon  \
# 0             0.0          0.0      0.0         NaN       Clear  clear-night
# 1             0.0          0.0      0.0         NaN       Clear  clear-night
# 2             0.0          0.0      0.0         NaN       Clear  clear-night
# 3             0.0          0.0      0.0         NaN       Clear  clear-night
# 4             0.0          0.0      0.0         NaN       Clear  clear-night
#
#                                    stations
# 0                          48820099999,VVNB
# 1  48820099999,48825099999,48831099999,VVNB
# 2                          48820099999,VVNB
# 3                                      VVNB
# 4              48820099999,48825099999,VVNB
#
# [5 rows x 24 columns]

# %%
hn_hourly.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 94248 entries, 0 to 94247
# Data columns (total 24 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              94248 non-null  object
#  1   datetime          94248 non-null  object
#  2   temp              94248 non-null  float64
#  3   feelslike         94248 non-null  float64
#  4   dew               94248 non-null  float64
#  5   humidity          94248 non-null  float64
#  6   precip            94209 non-null  float64
#  7   precipprob        94248 non-null  int64
#  8   preciptype        12055 non-null  object
#  9   snow              94206 non-null  float64
#  10  snowdepth         94206 non-null  float64
#  11  windgust          94199 non-null  float64
#  12  windspeed         94247 non-null  float64
#  13  winddir           94246 non-null  float64
#  14  sealevelpressure  94248 non-null  float64
#  15  cloudcover        94248 non-null  float64
#  16  visibility        94070 non-null  float64
#  17  solarradiation    94212 non-null  float64
#  18  solarenergy       94212 non-null  float64
#  19  uvindex           94212 non-null  float64
#  20  severerisk        32645 non-null  float64
#  21  conditions        94248 non-null  object
#  22  icon              94248 non-null  object
#  23  stations          94248 non-null  object
# dtypes: float64(17), int64(1), object(6)
# memory usage: 17.3+ MB

# %%
hn_hourly.describe()
# Out:
#                temp     feelslike           dew      humidity        precip  \
# count  94248.000000  94248.000000  94248.000000  94248.000000  94209.000000
# mean      24.896258     27.393700     20.485905     78.270513      0.217643
# std        5.613481      8.500585      5.931406     15.748502      2.647468
# min        5.900000      2.100000     -8.000000     17.590000      0.000000
# 25%       21.000000     21.000000     17.000000     67.360000      0.000000
# 50%       25.900000     25.900000     22.400000     81.880000      0.000000
# 75%       29.000000     34.200000     25.000000     91.340000      0.000000
# max       41.900000     52.500000     31.000000    100.000000    186.240000
#
#          precipprob     snow  snowdepth      windgust     windspeed  \
# count  94248.000000  94206.0    94206.0  94199.000000  94247.000000
# mean       8.245268      0.0        0.0     17.380778      9.318116
# std       27.505461      0.0        0.0      7.716193      4.824510
# min        0.000000      0.0        0.0      1.100000      0.000000
# 25%        0.000000      0.0        0.0     11.500000      5.600000
# 50%        0.000000      0.0        0.0     16.600000      8.500000
# 75%        0.000000      0.0        0.0     22.000000     12.100000
# max      100.000000      0.0        0.0    118.800000     53.600000
#
#             winddir  sealevelpressure    cloudcover    visibility  \
# count  94246.000000      94248.000000  94248.000000  94070.000000
# mean     142.613537       1011.082052     64.712259      8.599728
# std      104.672241          7.315970     34.604449      2.848757
# min        0.000000        985.000000      0.000000      0.000000
# 25%       65.000000       1005.000000     36.100000      7.000000
# 50%      115.000000       1010.900000     81.900000     10.000000
# 75%      185.000000       1016.800000     89.900000     10.000000
# max      360.000000       1041.000000    100.000000     24.100000
#
#        solarradiation   solarenergy       uvindex    severerisk
# count    94212.000000  94212.000000  94212.000000  32645.000000
# mean       155.174609      0.558068      1.545100     17.062031
# std        235.708445      0.849264      2.370613     15.945075
# min          0.000000      0.000000      0.000000      3.000000
# 25%          0.000000      0.000000      0.000000     10.000000
# 50%          5.800000      0.000000      0.000000     10.000000
# 75%        248.125000      0.900000      2.000000     15.000000
# max       1011.900000      3.600000     10.000000    100.000000

# %% [markdown]
# ### Xác định các loại biến (categorical vs numerical)

# %%
# Xác định các biến categorical và numerical
categorical_cols = hn_hourly.select_dtypes(include=['object', 'category']).columns.tolist()


numerical_cols = hn_hourly.select_dtypes(include=['float64', 'int64']).columns.tolist()
# Loại bỏ các cột low-cardinality khỏi numerical
numerical_cols = [col for col in numerical_cols if col not in categorical_cols]

print(f"📊 Số biến categorical: {len(categorical_cols)}")
print(f"Danh sách: {categorical_cols}\n")
print(f"📈 Số biến numerical: {len(numerical_cols)}")
print(f"Danh sách: {numerical_cols}")
# Out:
# 📊 Số biến categorical: 6
# Danh sách: ['name', 'datetime', 'preciptype', 'conditions', 'icon', 'stations']
#
# 📈 Số biến numerical: 18
# Danh sách: ['temp', 'feelslike', 'dew', 'humidity', 'precip', 'precipprob', 'snow', 'snowdepth', 'windgust', 'windspeed', 'winddir', 'sealevelpressure', 'cloudcover', 'visibility', 'solarradiation', 'solarenergy', 'uvindex', 'severerisk']

# %% [markdown]
# ## Train - Test Split

# %%
def train_test_split_hourly(df, train_ratio):
    """
    Chia train-test split cho dữ liệu hourly
    
    Args:
        df: DataFrame với cột datetime và temp
        train_ratio: Tỉ lệ dữ liệu train (0-1)
        gap_hours: Số giờ gap giữa train và test (mặc định 168 = 7 ngày)
    
    Returns:
        X_train, y_train, X_test, y_test
    """
    # Tạo bản sao để không ảnh hưởng dữ liệu gốc
    df = df.copy()
    
    # Chuyển đổi datetime sang dạng datetime nếu cần
    if df['datetime'].dtype == 'object':
        df['datetime'] = pd.to_datetime(df['datetime'])
    
    # Sắp xếp theo thời gian
    df = df.sort_values('datetime').reset_index(drop=True)
    
    # Tính kích thước train (không bao gồm gap)
    total_size = len(df)
    train_size = int(total_size * train_ratio)
    test_start = train_size

    
    # Chia dữ liệu
    train_data = df.iloc[:train_size]
    test_data = df.iloc[test_start:]
    
    print(f"📊 Kích thước tập huấn luyện: {train_data.shape}")
    print(f"📊 Kích thước tập kiểm tra: {test_data.shape}")
    print(f"⏱️  Khoảng thời gian train: {train_data['datetime'].min()} → {train_data['datetime'].max()}")
    print(f"⏱️  Khoảng thời gian test: {test_data['datetime'].min()} → {test_data['datetime'].max()}")
    
    # Chuẩn bị features và target
    feature_cols = df.columns.drop(['temp', 'datetime'])
    X_train = train_data[feature_cols]
    y_train = train_data['temp']
    X_test = test_data[feature_cols]
    y_test = test_data['temp']
    
    print(f"\n✅ X_train: {X_train.shape}, y_train: {y_train.shape}")
    print(f"✅ X_test: {X_test.shape}, y_test: {y_test.shape}")
    
    return X_train, y_train, X_test, y_test

# %% [markdown]
# ## Basic Processing

# %%
X_train, y_train, X_test, y_test = train_test_split_hourly(hn_hourly, train_ratio=0.8)
# Out:
# 📊 Kích thước tập huấn luyện: (75398, 24)
# 📊 Kích thước tập kiểm tra: (18850, 24)
# ⏱️  Khoảng thời gian train: 2015-01-01 00:00:00 → 2023-08-08 13:00:00
# ⏱️  Khoảng thời gian test: 2023-08-08 14:00:00 → 2025-10-01 23:00:00
#
# ✅ X_train: (75398, 22), y_train: (75398,)
# ✅ X_test: (18850, 22), y_test: (18850,)

# %%
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.feature_selection import VarianceThreshold
from sklearn.pipeline import Pipeline
import numpy as np

# Bước 1: Loại bỏ cột số có phương sai = 0
class VarianceThresholdSelector(BaseEstimator, TransformerMixin):
    def __init__(self, threshold=0):
        self.threshold = threshold
        self.selector = VarianceThreshold(threshold=self.threshold)
    
    def fit(self, X, y=None):
        numeric_cols = X.select_dtypes(include=['float64', 'int64']).columns
        self.numeric_cols = numeric_cols
        self.selector.fit(X[numeric_cols])
        # Lưu lại cột số được giữ lại
        self.retained_cols = numeric_cols[self.selector.get_support()]
        # Lưu lại cột số bị loại
        self.dropped_cols = [col for col in numeric_cols if col not in self.retained_cols]
        print("Các cột bị loại vì phương sai = 0:", self.dropped_cols)
        return self
    
    def transform(self, X):
        cols_to_keep = list(self.retained_cols) + list(X.columns.difference(self.numeric_cols))
        return X[cols_to_keep]

# Bước 2: Loại bỏ cột hằng số và dòng trùng lặp
class ConstantAndDuplicateRemover(BaseEstimator, TransformerMixin):
    def fit(self, X, y=None):
        # Xác định cột hằng số
        self.constant_cols = [col for col in X.columns if X[col].nunique() == 1]
        print("Các cột bị loại vì chỉ có 1 giá trị:", self.constant_cols)
        return self
    
    def transform(self, X):
        # Bỏ cột hằng số
        X_cleaned = X.drop(columns=self.constant_cols, errors="ignore")
        # Bỏ dòng trùng lặp (không in số lượng nữa)
        X_cleaned = X_cleaned.drop_duplicates()
        return X_cleaned

# %%
# Tạo pipeline
cleaning_pipeline = Pipeline(steps=[
    ("var_thresh", VarianceThresholdSelector(threshold=0)),
    ("const_dup", ConstantAndDuplicateRemover())

])
X_train_cleaned = cleaning_pipeline.fit_transform(X_train.copy())
X_test_cleaned = cleaning_pipeline.transform(X_test.copy())
print(f"Kích thước dữ liệu sau khi làm sạch: {X_train_cleaned.shape}")
print(f"Kích thước dữ liệu kiểm tra sau khi làm sạch: {X_test_cleaned.shape}")
# Out:
# Các cột bị loại vì phương sai = 0: ['snow', 'snowdepth']
# Các cột bị loại vì chỉ có 1 giá trị: ['name', 'preciptype']
# Kích thước dữ liệu sau khi làm sạch: (75392, 18)
# Kích thước dữ liệu kiểm tra sau khi làm sạch: (18845, 18)
# Kích thước dữ liệu sau khi làm sạch: (75392, 18)
# Kích thước dữ liệu kiểm tra sau khi làm sạch: (18845, 18)

# %%
# Tính correlation matrix chỉ cho các features số
train_cleaned_df = X_train_cleaned.copy().join(y_train.reset_index(drop=True), how='left')
numeric_cols = train_cleaned_df.select_dtypes(include=['float64', 'int64']).columns
correlation_matrix = train_cleaned_df[numeric_cols].corr()

print(f"📊 Số lượng features số: {len(numeric_cols)}")
print(f"📋 Danh sách features: {list(numeric_cols)}\n")
print("Correlation Matrix:")
correlation_matrix
# Out:
# 📊 Số lượng features số: 16
# 📋 Danh sách features: ['feelslike', 'dew', 'humidity', 'precip', 'precipprob', 'windgust', 'windspeed', 'winddir', 'sealevelpressure', 'cloudcover', 'visibility', 'solarradiation', 'solarenergy', 'uvindex', 'severerisk', 'temp']
#
# Correlation Matrix:
#                   feelslike       dew  humidity    precip  precipprob  \
# feelslike          1.000000  0.778382 -0.187820 -0.007467    0.022557
# dew                0.778382  1.000000  0.425183  0.041165    0.073150
# humidity          -0.187820  0.425183  1.000000  0.062860    0.067888
# precip            -0.007467  0.041165  0.062860  1.000000    0.284192
# precipprob         0.022557  0.073150  0.067888  0.284192    1.000000
# windgust           0.184836  0.056694 -0.227952  0.033731    0.058673
# windspeed          0.096138  0.011786 -0.136549 -0.019013   -0.011624
# winddir            0.048332  0.007350 -0.079299  0.021961    0.005709
# sealevelpressure  -0.818298 -0.833461 -0.125274 -0.045556   -0.039317
# cloudcover        -0.125419 -0.008803  0.157718  0.060450    0.115835
# visibility         0.368471  0.066089 -0.434988 -0.000068   -0.005279
# solarradiation     0.439189  0.077350 -0.532426 -0.026657    0.003718
# solarenergy        0.438887  0.077165 -0.532341 -0.026969    0.003371
# uvindex            0.437309  0.077163 -0.530417 -0.027462    0.002434
# severerisk         0.573217  0.394711 -0.089752  0.005827    0.001986
# temp               0.964693  0.789835 -0.212236  0.004227    0.031296
#
#                   windgust  windspeed   winddir  sealevelpressure  cloudcover  \
# feelslike         0.184836   0.096138  0.048332         -0.818298   -0.125419
# dew               0.056694   0.011786  0.007350         -0.833461   -0.008803
# humidity         -0.227952  -0.136549 -0.079299         -0.125274    0.157718
# precip            0.033731  -0.019013  0.021961         -0.045556    0.060450
# precipprob        0.058673  -0.011624  0.005709         -0.039317    0.115835
# windgust          1.000000   0.533517 -0.024487         -0.114727    0.151964
# windspeed         0.533517   1.000000 -0.178890         -0.081450    0.099088
# winddir          -0.024487  -0.178890  1.000000         -0.017475   -0.048075
# sealevelpressure -0.114727  -0.081450 -0.017475          1.000000    0.023014
# cloudcover        0.151964   0.099088 -0.048075          0.023014    1.000000
# visibility        0.219959   0.117515  0.045995         -0.194522   -0.009953
# solarradiation    0.354658   0.085979  0.095454         -0.165594   -0.045486
# solarenergy       0.354687   0.086192  0.095369         -0.165389   -0.045570
# uvindex           0.353783   0.085772  0.095068         -0.164648   -0.045442
# severerisk        0.102378   0.082938 -0.025273         -0.427579   -0.037493
# temp              0.214756   0.097161  0.065990         -0.821037   -0.120427
#
#                   visibility  solarradiation  solarenergy   uvindex  \
# feelslike           0.368471        0.439189     0.438887  0.437309
# dew                 0.066089        0.077350     0.077165  0.077163
# humidity           -0.434988       -0.532426    -0.532341 -0.530417
# precip             -0.000068       -0.026657    -0.026969 -0.027462
# precipprob         -0.005279        0.003718     0.003371  0.002434
# windgust            0.219959        0.354658     0.354687  0.353783
# windspeed           0.117515        0.085979     0.086192  0.085772
# winddir             0.045995        0.095454     0.095369  0.095068
# sealevelpressure   -0.194522       -0.165594    -0.165389 -0.164648
# cloudcover         -0.009953       -0.045486    -0.045570 -0.045442
# visibility          1.000000        0.257533     0.257515  0.257002
# solarradiation      0.257533        1.000000     0.999701  0.996348
# solarenergy         0.257515        0.999701     1.000000  0.996035
# uvindex             0.257002        0.996348     0.996035  1.000000
# severerisk          0.206091        0.338397     0.338028  0.336531
# temp                0.353255        0.452060     0.451781  0.450389
#
#                   severerisk      temp
# feelslike           0.573217  0.964693
# dew                 0.394711  0.789835
# humidity           -0.089752 -0.212236
# precip              0.005827  0.004227
# precipprob          0.001986  0.031296
# windgust            0.102378  0.214756
# windspeed           0.082938  0.097161
# winddir            -0.025273  0.065990
# sealevelpressure   -0.427579 -0.821037
# cloudcover         -0.037493 -0.120427
# visibility          0.206091  0.353255
# solarradiation      0.338397  0.452060
# solarenergy         0.338028  0.451781
# uvindex             0.336531  0.450389
# severerisk          1.000000  0.483034
# temp                0.483034  1.000000

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

plt.figure(figsize=(16, 12))

# Vẽ heatmap với annotation
sns.heatmap(correlation_matrix, 
            annot=True,           
            fmt='.2f',            
            cmap='coolwarm',      
            center=0,             
            square=True,          
            linewidths=0.5,       
            cbar_kws={"shrink": 0.8})

plt.title('Correlation Heatmap - Hanoi Daily Weather Data', fontsize=16, fontweight='bold', pad=20)
plt.xticks(rotation=45, ha='right')
plt.yticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
X_train_cleaned.drop(columns=['feelslike'], errors='ignore', inplace=True)
X_train_cleaned.columns
# Out:
# Index(['dew', 'humidity', 'precip', 'precipprob', 'windgust', 'windspeed',
#        'winddir', 'sealevelpressure', 'cloudcover', 'visibility',
#        'solarradiation', 'solarenergy', 'uvindex', 'severerisk', 'conditions',
#        'icon', 'stations'],
#       dtype='object')

# %%
X_test_cleaned.drop(columns=['feelslike'], errors='ignore', inplace=True)
X_test_cleaned.columns
# Out:
# Index(['dew', 'humidity', 'precip', 'precipprob', 'windgust', 'windspeed',
#        'winddir', 'sealevelpressure', 'cloudcover', 'visibility',
#        'solarradiation', 'solarenergy', 'uvindex', 'severerisk', 'conditions',
#        'icon', 'stations'],
#       dtype='object')

# %% [markdown]
# ## Correlation Analysis for Categorical and Mixed Variables
#
# ### 1. Categorical-Categorical Correlation: Cramér's V
# Cramér's V đo lường mối quan hệ giữa 2 biến categorical dựa trên chi-square test. Giá trị từ 0 (không có mối quan hệ) đến 1 (mối quan hệ hoàn hảo).
#
# ### 2. Numerical-Categorical Correlation: Correlation Ratio (η²)
# Correlation ratio (eta-squared) đo lường mức độ một biến categorical giải thích được sự biến thiên của một biến numerical. Giá trị từ 0 đến 1.

# %%
# Import thư viện cần thiết
import numpy as np
from scipy.stats import chi2_contingency
import warnings
warnings.filterwarnings('ignore')

# Hàm tính Cramér's V cho categorical-categorical correlation
def cramers_v(x, y):
    """
    Tính Cramér's V giữa 2 biến categorical
    V = sqrt(chi2 / (n * (min(k,r) - 1)))
    """
    # Loại bỏ missing values
    mask = ~(pd.isna(x) | pd.isna(y))
    x_clean = x[mask]
    y_clean = y[mask]
    
    if len(x_clean) == 0:
        return np.nan
    
    # Tạo contingency table
    confusion_matrix = pd.crosstab(x_clean, y_clean)
    
    # Chi-square test
    chi2, _, _, _ = chi2_contingency(confusion_matrix)
    
    n = confusion_matrix.sum().sum()
    min_dim = min(confusion_matrix.shape[0], confusion_matrix.shape[1]) - 1
    
    if min_dim == 0:
        return 0
    
    v = np.sqrt(chi2 / (n * min_dim))
    return v

# Hàm tính correlation ratio (eta-squared) cho numerical-categorical correlation
def correlation_ratio(categories, values):
    """
    Tính correlation ratio (η²) giữa biến categorical và numerical
    η² = SSB / SST (Sum of Squares Between / Sum of Squares Total)
    """
    # Loại bỏ missing values
    mask = ~(pd.isna(categories) | pd.isna(values))
    categories_clean = categories[mask]
    values_clean = values[mask]
    
    if len(values_clean) == 0:
        return np.nan
    
    # Tính mean tổng thể
    mean_total = values_clean.mean()
    
    # Tính SST (Total Sum of Squares)
    sst = np.sum((values_clean - mean_total) ** 2)
    
    if sst == 0:
        return 0
    
    # Tính SSB (Between group Sum of Squares)
    ssb = 0
    for category in categories_clean.unique():
        group_values = values_clean[categories_clean == category]
        group_mean = group_values.mean()
        group_size = len(group_values)
        ssb += group_size * (group_mean - mean_total) ** 2
    
    # η² = SSB / SST
    eta_squared = ssb / sst
    return eta_squared

print("✅ Đã định nghĩa các hàm tính correlation")
# Out:
# ✅ Đã định nghĩa các hàm tính correlation

# %% [markdown]
# ### Tính Categorical-Categorical Correlation (Cramér's V)

# %%
# Cập nhật lại categorical_cols để chỉ giữ các cột còn tồn tại trong df
categorical_cols_cleaned = [col for col in categorical_cols if col in X_cleaned.columns]

# Tính Cramér's V matrix cho tất cả các cặp biến categorical còn lại
if len(categorical_cols_cleaned) > 0:
    cat_cat_corr = pd.DataFrame(
        np.zeros((len(categorical_cols_cleaned), len(categorical_cols_cleaned))),
        index=categorical_cols_cleaned,
        columns=categorical_cols_cleaned
    )

    for i, col1 in enumerate(categorical_cols_cleaned):
        for j, col2 in enumerate(categorical_cols_cleaned):
            if i <= j:  # Chỉ tính nửa trên của ma trận (symmetric)
                v = cramers_v(X_cleaned[col1], X_cleaned[col2])
                cat_cat_corr.loc[col1, col2] = v
                cat_cat_corr.loc[col2, col1] = v

    print("📊 Cramér's V Matrix (Categorical-Categorical):")
    display(cat_cat_corr)
else:
    print("⚠️ Không còn cột categorical nào trong X_cleaned để phân tích!")
# Out:
# 📊 Cramér's V Matrix (Categorical-Categorical):
#             conditions      icon  stations
# conditions    1.000000  0.774559  0.188169
# icon          0.774559  1.000000  0.137771
# stations      0.188169  0.137771  1.000000

# %%
# Visualize Cramér's V matrix
if len(categorical_cols) > 0:
    plt.figure(figsize=(10, 8))
    sns.heatmap(cat_cat_corr, 
                annot=True, 
                fmt='.3f', 
                cmap='YlOrRd',
                square=True,
                linewidths=0.5,
                cbar_kws={"shrink": 0.8},
                vmin=0, vmax=1)
    plt.title("Cramér's V - Categorical-Categorical Correlation", fontsize=14, fontweight='bold', pad=15)
    plt.xticks(rotation=45, ha='right')
    plt.yticks(rotation=0)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### Tính Numerical-Categorical Correlation (Correlation Ratio η²)

# %%
train_df_cleaned = pd.concat([X_cleaned, y_train], axis=1)
categorical_cols_cleaned = [col for col in categorical_cols if col in train_df_cleaned.columns]

print(f"📋 Categorical columns trong data: {categorical_cols_cleaned}")

# ✅ Cập nhật numerical_cols để chỉ lấy các cột có trong X_cleaned
numerical_cols_cleaned = [col for col in numerical_cols if col in train_df_cleaned.columns]
print(f"📋 Numerical columns trong data: {numerical_cols_cleaned}")

# Tính correlation ratio (η²) giữa numerical và categorical
if len(categorical_cols_cleaned) > 0:
    num_cat_corr = pd.DataFrame(
        np.zeros((len(numerical_cols_cleaned), len(categorical_cols_cleaned))),
        index=numerical_cols_cleaned,
        columns=categorical_cols_cleaned
    )

    for num_col in numerical_cols_cleaned:
        for cat_col in categorical_cols_cleaned:
            eta = correlation_ratio(train_df_cleaned[cat_col], train_df_cleaned[num_col])
            num_cat_corr.loc[num_col, cat_col] = eta

    print("📊 Correlation Ratio Matrix (Numerical-Categorical):")
    display(num_cat_corr)
else:
    print("⚠️ Không còn cột categorical nào trong X_cleaned để phân tích!")
# Out:
# 📋 Categorical columns trong data: ['conditions', 'icon', 'stations']
# 📋 Numerical columns trong data: ['temp', 'dew', 'humidity', 'precip', 'precipprob', 'windgust', 'windspeed', 'winddir', 'sealevelpressure', 'cloudcover', 'visibility', 'solarradiation', 'solarenergy', 'uvindex', 'severerisk']
# 📊 Correlation Ratio Matrix (Numerical-Categorical):
# 📊 Correlation Ratio Matrix (Numerical-Categorical):
#                   conditions      icon  stations
# temp                0.051782  0.093099  0.001336
# dew                 0.053102  0.057686  0.001382
# humidity            0.017494  0.144578  0.000909
# precip              0.107508  0.080765  0.027864
# precipprob          1.000000  1.000000  0.082839
# windgust            0.036315  0.105404  0.001556
# windspeed           0.028581  0.035420  0.078470
# winddir             0.003465  0.006897  0.009449
# sealevelpressure    0.028526  0.032206  0.001188
# cloudcover          0.722698  0.698489  0.036460
# visibility          0.004320  0.016888  0.107452
# solarradiation      0.028894  0.376056  0.000879
# solarenergy         0.028883  0.375407  0.000907
# uvindex             0.028762  0.372472  0.001018
# severerisk          0.060695  0.103307  0.003319

# %%
# Visualize Numerical-Categorical correlation
if len(numerical_cols) > 0 and len(categorical_cols) > 0:
    max_rows = min(20, len(numerical_cols))
    
    plt.figure(figsize=(12, max(8, max_rows * 0.4)))
    sns.heatmap(num_cat_corr.iloc[:max_rows], 
                annot=True, 
                fmt='.3f', 
                cmap='RdYlGn',
                linewidths=0.5,
                cbar_kws={"shrink": 0.8}, 
                vmin=0, vmax=1)
    plt.title(f"Correlation Ratio (η²) - Numerical-Categorical (Top {max_rows} vars)", 
              fontsize=14, fontweight='bold', pad=15)
    plt.xlabel('Categorical Variables')
    plt.ylabel('Numerical Variables')
    plt.xticks(rotation=45, ha='right')
    plt.yticks(rotation=0)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## Outlier Detecting

# %%
# Xử lí outlier cho numerical data
# vẽ biểu dồ boxplot để quan sát outliers
import matplotlib.pyplot as plt
import seaborn as sns

num_cols_for_plot = X_train_cleaned.select_dtypes(include=np.number).columns.tolist()
plt.figure(figsize=(10, 6))
sns.boxplot(data=X_train_cleaned[num_cols_for_plot], orient='h')
plt.title('Boxplot of Numerical Features - Hanoi Daily Weather Data', fontsize=16, fontweight='bold')
plt.xlabel('Value')
plt.ylabel('Features')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Outlier Handling Rationale
# We will clipping instead of removal. Because:
#
# 1. **Temporal Dependency Preservation**
#    - Time series requires continuous sequential data
#    - Removing observations creates gaps that break temporal patterns
#    - Models like LSTM/GRU need uninterrupted sequences
#
# 2. **Physical Reality**
#    - Outliers represent extreme weather events (storms, heatwaves)
#    - These are valid measurements, not errors
#    - Removal loses critical information about climate variability
#
# 3. **Domain-Based Boundaries**
#    - Physical constraints are well-defined (e.g., humidity: 0-100%)
#    - Values exceeding limits are measurement errors, not natural phenomena
#    - Clipping corrects sensor errors while preserving temporal continuity
#
# 4. **Statistical Considerations**
#    - Small dataset (~8,000 hourly records) - cannot afford data loss
#    - Outliers may be rare but informative for prediction
#    - Clipping maintains sample size for model training

# %%
class OutlierHandler(BaseEstimator, TransformerMixin):
    """
    Xử lý outliers dựa trên domain knowledge và IQR method
    """
    def __init__(self, method='clip'):
        self.method = method
        self.bounds = {}
    
    def fit(self, X, y=None):
        """Học boundaries từ training data"""
        for col in X.select_dtypes(include=[np.number]).columns:
            Q1 = X[col].quantile(0.25)
            Q3 = X[col].quantile(0.75)
            IQR = Q3 - Q1
            
            # Physical constraints cho từng biến
            if col == 'solarradiation':
                # Max solar radiation ~1361 W/m² (solar constant)
                lower = 0
                upper = 1400
            elif col == 'precip':
                # Lượng mưa không âm, max ~50mm/hour (extreme)
                lower = 0
                upper = 50
            elif col == 'winddir':
                # Wind direction: 0-360°
                lower = 0
                upper = 360
            elif col == 'sealevelpressure':
                # Pressure: 950-1050 hPa (reasonable range)
                lower = 950
                upper = 1050
            elif col == 'humidity':
                # Humidity: 0-100%
                lower = 0
                upper = 100
            elif col == 'windspeed' or col == 'windgust':
                # Wind speed: không âm, max ~50 m/s
                lower = 0
                upper = X[col].quantile(0.99)  # 99th percentile
            else:
                # IQR method cho các biến khác
                lower = Q1 - 1.5 * IQR
                upper = Q3 + 1.5 * IQR
            
            self.bounds[col] = (lower, upper)
        
        return self
    
    def transform(self, X):
        """Apply outlier handling"""
        X = X.copy()
        
        for col, (lower, upper) in self.bounds.items():
            if col in X.columns:
                if self.method == 'clip':
                    # Clip outliers to boundaries
                    X[col] = X[col].clip(lower=lower, upper=upper)
                elif self.method == 'winsorize':
                    # Winsorize at boundaries
                    X[col] = np.where(X[col] < lower, lower, X[col])
                    X[col] = np.where(X[col] > upper, upper, X[col])
        
        return X

# %%
# Apply outlier handling
outlier_handler = OutlierHandler(method='clip')
X_train_after_outlier = outlier_handler.fit_transform(X_train_cleaned.copy())
X_test_after_outlier = outlier_handler.transform(X_test_cleaned.copy())

print("✅ Đã xử lý outliers")
# Out:
# ✅ Đã xử lý outliers

# %% [markdown]
# ## Handle missing value

# %%
missing = X_train_after_outlier.isna().sum().sort_values(ascending=False)
missing_pct = (X_train_after_outlier.isna().mean().sort_values(ascending=False))*100
pd.concat([missing, missing_pct], axis=1, keys=["missing","percent"])
# Out:
#                   missing    percent
# severerisk          61598  81.703629
# visibility            178   0.236099
# windgust               48   0.063667
# precip                 38   0.050403
# solarradiation         35   0.046424
# uvindex                35   0.046424
# solarenergy            35   0.046424
# winddir                 2   0.002653
# windspeed               1   0.001326
# dew                     0   0.000000
# sealevelpressure        0   0.000000
# humidity                0   0.000000
# precipprob              0   0.000000
# cloudcover              0   0.000000
# conditions              0   0.000000
# icon                    0   0.000000
# stations                0   0.000000

# %% [markdown]
# ### Missing Value Imputation Strategy
#
# **1. Drop: severerisk (81.7% missing)**
# - Excessive missing rate leads to unreliable imputation and potential bias
#
# **2. Forward/Backward Fill: visibility, windspeed, winddir, sealevelpressure**
# - Meteorological variables exhibit temporal continuity (slow-changing patterns)
# - Forward fill assumes persistence over short intervals; backward fill handles series start
#
# **3. Conditional Imputation: precip (0.05% missing)**
# - Domain logic: precipprob = 0 → precip = 0 (no rain expected)
# - Remaining cases: median imputation (robust to outliers in skewed distribution)
#
# **4. Time-based + Interpolation: solarradiation, solarenergy, uvindex (~0.046% missing)**
# - Physical constraint: nighttime or heavy cloud cover (≥90%) → solar = 0
# - Daytime gaps: linear interpolation leverages diurnal sinusoidal pattern
#
# **5. KNN Imputation: windgust (0.06% missing)**
# - High correlation between wind variables (speed, direction, gust)
# - KNN captures multivariate relationships using k=5 neighbors with distance weighting

# %%
from sklearn.impute import SimpleImputer, KNNImputer

class MissingValueHandlerHourly(BaseEstimator, TransformerMixin):
    def __init__(self):
        self.knn_imputer = KNNImputer(n_neighbors=5, weights='distance')
        self.medians = {}
    
    def fit(self, X, y=None):
        # Lưu median values
        for col in X.select_dtypes(include=[np.number]).columns:
            self.medians[col] = X[col].median()
        
        # Fit KNN imputer
        wind_cols = ['windspeed', 'winddir', 'windgust']
        if all(col in X.columns for col in wind_cols):
            self.knn_imputer.fit(X[wind_cols])
        
        return self
    
    def transform(self, X):
        X = X.copy()
        
        # 1. Drop severerisk
        X.drop(columns=['severerisk'], inplace=True, errors='ignore')
        
        # 2. Forward fill time series
        time_cols = ['visibility', 'windspeed', 'winddir', 'sealevelpressure']
        for col in time_cols:
            if col in X.columns:
                X[col] = X[col].fillna(method='ffill').fillna(method='bfill')
        
        # 3. Conditional precip
        if 'precip' in X.columns:
            X.loc[X['precip'].isna() & (X['precipprob'] == 0), 'precip'] = 0
            X['precip'].fillna(self.medians.get('precip', 0), inplace=True)
        
        # 4. Solar features
        solar_cols = ['solarradiation', 'solarenergy', 'uvindex']
        for col in solar_cols:
            if col in X.columns:
                X.loc[(X[col].isna()) & (X.get('is_night', 0) == 1), col] = 0
                X[col] = X[col].interpolate(method='linear').fillna(0)
        
        # 5. KNN for wind
        wind_cols = ['windspeed', 'winddir', 'windgust']
        if all(col in X.columns for col in wind_cols):
            X[wind_cols] = self.knn_imputer.transform(X[wind_cols])
        
        return X

# %%
# Sử dụng MissingValueHandlerHourly để xử lý missing values với X_train đã làm sạch
mv_handler = MissingValueHandlerHourly()
X_train_imputed = mv_handler.fit_transform(X_train_after_outlier.copy())
missing_after = X_train_imputed.isna().sum().sort_values(ascending=False)
missing_pct_after = (X_train_imputed.isna().mean().sort_values(ascending=False))*100
pd.concat([missing_after, missing_pct_after], axis=1, keys=["missing_after","percent_after"])
# Out:
#                   missing_after  percent_after
# dew                           0            0.0
# humidity                      0            0.0
# precip                        0            0.0
# precipprob                    0            0.0
# windgust                      0            0.0
# windspeed                     0            0.0
# winddir                       0            0.0
# sealevelpressure              0            0.0
# cloudcover                    0            0.0
# visibility                    0            0.0
# solarradiation                0            0.0
# solarenergy                   0            0.0
# uvindex                       0            0.0
# conditions                    0            0.0
# icon                          0            0.0
# stations                      0            0.0

# %%
# sử dụng MissingValueHandlerHourly để xử lý missing values với X_test
X_test_imputed = mv_handler.transform(X_test_after_outlier.copy())
missing_after = X_test_imputed.isna().sum().sort_values(ascending=False)
missing_pct_after = (X_test_imputed.isna().mean().sort_values(ascending=False))*100
pd.concat([missing_after, missing_pct_after], axis=1, keys=["missing_after","percent_after"])
# Out:
#                   missing_after  percent_after
# dew                           0            0.0
# humidity                      0            0.0
# precip                        0            0.0
# precipprob                    0            0.0
# windgust                      0            0.0
# windspeed                     0            0.0
# winddir                       0            0.0
# sealevelpressure              0            0.0
# cloudcover                    0            0.0
# visibility                    0            0.0
# solarradiation                0            0.0
# solarenergy                   0            0.0
# uvindex                       0            0.0
# conditions                    0            0.0
# icon                          0            0.0
# stations                      0            0.0

# %%
# Concatenate train and test data with target variable
train_processed = pd.concat([X_train_imputed, y_train.reset_index(drop=True)], axis=1)
test_processed = pd.concat([X_test_imputed, y_test.reset_index(drop=True)], axis=1)

print(f"📊 Train processed shape: {train_processed.shape}")
print(f"📊 Test processed shape: {test_processed.shape}")

# Save to CSV files in processed folder
train_processed.to_csv('../dataset/processed/train_hourly_processed.csv', index=False)
test_processed.to_csv('../dataset/processed/test_hourly_processed.csv', index=False)

print("\n✅ Đã lưu files:")
print("   - ../dataset/processed/train_hourly_processed.csv")
print("   - ../dataset/processed/test_hourly_processed.csv")
# Out:
# 📊 Train processed shape: (75398, 17)
# 📊 Test processed shape: (37695, 17)
#
# ✅ Đã lưu files:
#    - ../dataset/processed/train_hourly_processed.csv
#    - ../dataset/processed/test_hourly_processed.csv
#
# ✅ Đã lưu files:
#    - ../dataset/processed/train_hourly_processed.csv
#    - ../dataset/processed/test_hourly_processed.csv
